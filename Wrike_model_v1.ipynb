# %%
import requests
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from bs4 import BeautifulSoup
from nltk.stem import PorterStemmer

# %%
def get_html(url):
    site = requests.get(url)
    html = BeautifulSoup(site.text, 'html.parser')
    return html

# %% [markdown]
# <h2>Parsing Wrike's knowledge base

# %%
def get_list_of_articles(url):
    help_url = 'https://help.wrike.com'
    res = []
    html = get_html(url)
    articles = html.find('ul', class_ = 'article-list')
    lis = articles.find_all('li')
    for li in lis:
        res.append(help_url + li.find('a').get('href'))
    return res

# %%
porter = PorterStemmer()

def text_normalization(text):
    res = []
    if (type(text) != str):
        text = str(text)
    text = text.lower()
    
    #Text cleaning
    trash_symbols = "!”#$%&’'()*+-,.:;<=>?@[]\|/^_`{}~]\"\'"
    for i in range(len(trash_symbols)):
        text = text.replace(trash_symbols[i], '')
    text = text.replace('  ', ' ')
    
    #Tokenizing
    text = text.split(' ')
    #Stamming and using only useful words
    trash_words = ['', 'a', 'an', 'the', 'or']
    for word in text:
        if(word not in trash_words):
            res.append(porter.stem(word))
    return res

# %%
def knowledge_base_parsing(url):
    cols = ['url', 'type', 'title', 'norm_title', 'answer']
    df = pd.DataFrame(columns=cols)
    
    html = get_html(url)
    body = html.find('div', class_='article-body')
    if(body.h2 == None):
        if(body.h3 != None):
            text = body.h3.next_element
        else:
            return df
    else:
        text = body.h2.next_element
    
    for k in range(100):
        has_title = 0
        answer = []
        for i in range(100):
            text = text.next_element
            if(str(text).find('<h2>') != -1 or str(text).find('Facebook') != -1): #end of answer or page
                break
            #print('i = ', i, ', text = ', text)
            if(i == 1 and str(text).find('<') == -1):
                has_title = 1
                title = str(text).lower() #raw title
                
                #print('--- How to ' + title + ':')
                norm_title = text_normalization(text)
            if(i > 1 and len(text) > 1):
                if (str(text).find('<') == -1):
                    answer.append(str(text))
                    
        answer = ' '.join(answer)
        #Fixing some artifacts in text
        answer = answer.replace(" .", ".")
        answer = answer.replace("  ", " ")
        answer = answer.replace("\xa0", "")
        #print(answer)
        
        if(has_title == 1):
            #Adding to pandas dataframe
            df = df.append({
                'url' : url,
                'type' : 'How to',
                'title' : title, 
                'norm_title' : norm_title,
                'answer' : answer
            }, ignore_index=True)
        
        if(str(text).find('Facebook') != -1):
            break
        text = text.next_element
    if('overview' == df['norm_title'][0][0]):
        df = df.iloc[1:]
    return df

# %%
cols = ['url', 'type', 'title', 'norm_title', 'answer']
data = pd.DataFrame(columns=cols)

# %%
knowledgebase1 = [
    #Place here url, linked as 'See all N articles' in categories
    #With category url itself it won't work!
    
    #From category Tasks Folders Projects and Spaces
    'https://help.wrike.com/hc/en-us/sections/201893035-Tasks',
    'https://help.wrike.com/hc/en-us/sections/201834249-Folders-and-Projects',
    'https://help.wrike.com/hc/en-us/sections/202366329-Proofing-and-Approvals',
    'https://help.wrike.com/hc/en-us/sections/201893055-Communication',
    'https://help.wrike.com/hc/en-us/sections/201834259-Advanced',
    #'https://help.wrike.com/hc/en-us/sections/201893045-Organization', #link has some unusual html tree in article
    
    #From category Types of Accounts and Licenses
    'https://help.wrike.com/hc/en-us/sections/201893095-Accounts',
    
    #From category Work Views
    'https://help.wrike.com/hc/en-us/sections/201893075-Gantt-Chart',
    
    #From category Monitoring Panel
    'https://help.wrike.com/hc/en-us/sections/360004618833-Wrike-Resource',
    'https://help.wrike.com/hc/en-us/sections/201893085-Reporting',
    
    #From category Integrations
    'https://help.wrike.com/hc/en-us/sections/202365749-Wrike-GitHub-and-JIRA-Syncs',
    'https://help.wrike.com/hc/en-us/sections/202423365-Everything-Else',
    
     #From category Account Management
    'https://help.wrike.com/hc/en-us/sections/360000935413-Troubleshooting',
    'https://help.wrike.com/hc/en-us/sections/201825379-General-Account-Management',
    'https://help.wrike.com/hc/en-us/sections/201828169-Personal-User-License',
    
     #From category Security
    'https://help.wrike.com/hc/en-us/sections/201893105-Single-Sign-On',
    'https://help.wrike.com/hc/en-us/sections/201834349-More-Security-Features',
    
]

# %%
for chapter in  knowledgebase1:
    articles = get_list_of_articles(chapter)
    excluded_urls = [
        'https://help.wrike.com/hc/en-us/articles/210323225-Task-View',
        'https://help.wrike.com/hc/en-us/articles/360024767374-Wrike-Resource-Overview',
    ]
    for url in articles:
        if(url not in excluded_urls): #unusual html tree
            print(url + ' added')
            data = pd.concat([data, knowledge_base_parsing(url)])
# Out:
# https://help.wrike.com/hc/en-us/articles/209603709-Tasks added
# https://help.wrike.com/hc/en-us/articles/210323245-Subtasks added
# https://help.wrike.com/hc/en-us/articles/115005055469-Subtask-Alignment- added
# https://help.wrike.com/hc/en-us/articles/209603309-Attachments added
# https://help.wrike.com/hc/en-us/articles/209603689-Milestones added
# https://help.wrike.com/hc/en-us/articles/210323205-Backlogged-Tasks added
# https://help.wrike.com/hc/en-us/articles/210323325-List-View-Sorting-and-Prioritizing-Tasks added
# https://help.wrike.com/hc/en-us/articles/209603889-Mass-Editing added
# https://help.wrike.com/hc/en-us/articles/209603849-Sharing-Tasks added
# https://help.wrike.com/hc/en-us/articles/209603869-Duplicate-Tasks-and-Subtasks added
# https://help.wrike.com/hc/en-us/articles/115005179609-Star-a-Task added
# https://help.wrike.com/hc/en-us/articles/209603829-Importance added
# https://help.wrike.com/hc/en-us/articles/209603789-Task-Status added
# https://help.wrike.com/hc/en-us/articles/209603729-Request-a-Status-Update added
# https://help.wrike.com/hc/en-us/articles/209603769-Make-a-Task-Recurrent added
# https://help.wrike.com/hc/en-us/articles/210323305-Delete-Tasks added
# https://help.wrike.com/hc/en-us/articles/209603749-Print-Tasks added
# https://help.wrike.com/hc/en-us/articles/209603609-Create-Color-Code-and-Edit-Folders-and-Projects added
# https://help.wrike.com/hc/en-us/articles/209603389-Folder-and-Project-Info-Panels added
# https://help.wrike.com/hc/en-us/articles/209603489-Projects added
# https://help.wrike.com/hc/en-us/articles/115001778165-Project-Wizard-and-Default-View-Picker added
# https://help.wrike.com/hc/en-us/articles/209603649-Subfolders-and-Subprojects added
# https://help.wrike.com/hc/en-us/articles/209603669-Sharing-Folders-and-Projects added
# https://help.wrike.com/hc/en-us/articles/209603589-Access-Roles added
# https://help.wrike.com/hc/en-us/articles/210323005-Duplicate-a-Folder-or-Project added
# https://help.wrike.com/hc/en-us/articles/360000254229-Wrike-Okta-User-Provisioning added
# https://help.wrike.com/hc/en-us/articles/360046791773-Wrike-and-Azure-Active-Directory-User-Provisioning added
# https://help.wrike.com/hc/en-us/articles/360008652293-Workweek-Settings added
# https://help.wrike.com/hc/en-us/articles/360008652093-Language-Settings added
# https://help.wrike.com/hc/en-us/articles/360008254873-Workspace-Themes added
# https://help.wrike.com/hc/en-us/articles/360006918953-Work-Schedules-for-Users added
# https://help.wrike.com/hc/en-us/articles/210324405-Email-Notifications added
# https://help.wrike.com/hc/en-us/articles/209605589-Daily-To-Do-Emails added
# https://help.wrike.com/hc/en-us/articles/209605569-Add-or-Delete-an-Email added
# https://help.wrike.com/hc/en-us/articles/210324385-Upload-an-Avatar added
# https://help.wrike.com/hc/en-us/articles/209605549-Passwords added
# https://help.wrike.com/hc/en-us/articles/210324365-Personal-Profile added
# https://help.wrike.com/hc/en-us/articles/209605529-Time-and-Date-Settings added
# https://help.wrike.com/hc/en-us/articles/209605509-Desktop-Notifications added
# https://help.wrike.com/hc/en-us/articles/209605489-Multiple-Accounts added
# https://help.wrike.com/hc/en-us/articles/360033753394-SSO-with-OneLogin added
# https://help.wrike.com/hc/en-us/articles/360034273733-SSO-with-Azure added
# https://help.wrike.com/hc/en-us/articles/209605769-SSO-with-SAML-Implementation-Guide added
# https://help.wrike.com/hc/en-us/articles/210324565-SSO-with-SAML-User-Guide added
# https://help.wrike.com/hc/en-us/articles/210324545-SSO-with-Microsoft-Credentials-User-Guide added
# https://help.wrike.com/hc/en-us/articles/210324525-SSO-with-Microsoft-Credentials-Implementation-Guide added
# https://help.wrike.com/hc/en-us/articles/210324505-SSO-with-Okta added
# https://help.wrike.com/hc/en-us/articles/360012347934-Wrike-Lock added
# https://help.wrike.com/hc/en-us/articles/115004562769-European-Data-Center added
# https://help.wrike.com/hc/en-us/articles/115004530005-Deactivate-Users added
# https://help.wrike.com/hc/en-us/articles/210324485-Advanced-Security-Settings added
# https://help.wrike.com/hc/en-us/articles/210324465-One-Time-Passwords added
# https://help.wrike.com/hc/en-us/articles/209605749-Account-Backup added
# https://help.wrike.com/hc/en-us/articles/210324445-2-Step-Verification added

# %%
data.index = range(len(data))
data
# Out:
#                                                    url    type  \
# 0    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 1    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 2    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 3    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 4    https://help.wrike.com/hc/en-us/articles/20960...  How to
# ..                                                 ...     ...
# 817  https://help.wrike.com/hc/en-us/articles/21032...  How to
# 818  https://help.wrike.com/hc/en-us/articles/21032...  How to
# 819  https://help.wrike.com/hc/en-us/articles/21032...  How to
# 820  https://help.wrike.com/hc/en-us/articles/21032...  How to
# 821  https://help.wrike.com/hc/en-us/articles/21032...  How to
#
#                                                  title  \
# 0                                        create a task
# 1                                        assign a task
# 2                                      schedule a task
# 3             tag a task (organize tasks into folders)
# 4                                        follow a task
# ..                                                 ...
# 817                                authentication apps
# 818    enable 2-step verification (for a user license)
# 819  enable 2-step verification (for all users on a...
# 820                    reconfigure 2-step verification
# 821   disable 2-step verification for a user's license
#
#                                             norm_title  \
# 0                                        [creat, task]
# 1                                       [assign, task]
# 2                                      [schedul, task]
# 3               [tag, task, organ, task, into, folder]
# 4                                       [follow, task]
# ..                                                 ...
# 817                                     [authent, app]
# 818           [enabl, 2step, verif, for, user, licens]
# 819  [enabl, 2step, verif, for, all, user, on, subs...
# 820                         [reconfigur, 2step, verif]
# 821          [disabl, 2step, verif, for, users licens]
#
#                                                 answer
# 0    Select a Folder or Project from the left-hand ...
# 1    Choose the names of people to whom you want to...
# 2    In the List view, you can set or change the st...
# 3    When you tag a task, you're adding it to a Fol...
# 4    Following a task is agreat way to stay up-to-d...
# ..                                                 ...
# 817  To use 2-step verification you must have an au...
# 818  Download an authentication app on your mobile ...
# 819  This action must be done by an account admin. ...
# 820  If you would like to use 2-step verification w...
# 821  If 2-step verification has been turned on for ...
#
# [822 rows x 5 columns]

# %%
#Clear data
data = data.drop_duplicates(subset ="title")
data = data[data['title'].map(len) < 50]
data.index = range(len(data))
data
# Out:
#                                                    url    type  \
# 0    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 1    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 2    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 3    https://help.wrike.com/hc/en-us/articles/20960...  How to
# 4    https://help.wrike.com/hc/en-us/articles/20960...  How to
# ..                                                 ...     ...
# 384  https://help.wrike.com/hc/en-us/articles/20960...  How to
# 385  https://help.wrike.com/hc/en-us/articles/21032...  How to
# 386  https://help.wrike.com/hc/en-us/articles/21032...  How to
# 387  https://help.wrike.com/hc/en-us/articles/21032...  How to
# 388  https://help.wrike.com/hc/en-us/articles/21032...  How to
#
#                                                 title  \
# 0                                       create a task
# 1                                       assign a task
# 2                                     schedule a task
# 3            tag a task (organize tasks into folders)
# 4                                       follow a task
# ..                                                ...
# 384      perform an account backup (with attachments)
# 385                               authentication apps
# 386   enable 2-step verification (for a user license)
# 387                   reconfigure 2-step verification
# 388  disable 2-step verification for a user's license
#
#                                     norm_title  \
# 0                                [creat, task]
# 1                               [assign, task]
# 2                              [schedul, task]
# 3       [tag, task, organ, task, into, folder]
# 4                               [follow, task]
# ..                                         ...
# 384   [perform, account, backup, with, attach]
# 385                             [authent, app]
# 386   [enabl, 2step, verif, for, user, licens]
# 387                 [reconfigur, 2step, verif]
# 388  [disabl, 2step, verif, for, users licens]
#
#                                                 answer
# 0    Select a Folder or Project from the left-hand ...
# 1    Choose the names of people to whom you want to...
# 2    In the List view, you can set or change the st...
# 3    When you tag a task, you're adding it to a Fol...
# 4    Following a task is agreat way to stay up-to-d...
# ..                                                 ...
# 384  You can run a backup, which includes attachmen...
# 385  To use 2-step verification you must have an au...
# 386  Download an authentication app on your mobile ...
# 387  If you would like to use 2-step verification w...
# 388  If 2-step verification has been turned on for ...
#
# [389 rows x 5 columns]

# %%
data.to_csv('how_to_data.csv', index=False)

# %% [markdown]
# <h2>TF-IDF model

# %%
data = pd.read_csv('how_to_data.csv')

# %%
corpus = list(map(' '.join, data['norm_title'].values))
corpus.remove('\n')
corpus.remove('')

# %%
temp = []
for doc in corpus:
    temp.append(doc.replace('\xa0', ' '))
corpus = temp

# %%
corpus = ['How to ' + s for s in corpus]

# %%
corpus
# Out:
# ['How to creat task',
#  'How to assign task',
#  'How to schedul task',
#  'How to tag task organ task into folder',
#  'How to follow task',
#  'How to unfollow task',
#  'How to print task',
#  'How to add depend to task',
#  'How to view task',
#  'How to import inform',
#  'How to creat a subtask',
#  'How to view task subtask',
#  'How to edit subtask',
#  'How to convert task into subtask',
#  'How to convert subtask into task',
#  'How to add subtask to multipl parent task',
#  'How to chang subtask parent task',
#  'How to reorder subtask on list view',
#  'How to expand parent task date',
#  'How to shift task date',
#  'How to except',
#  'How to disabl align popup',
#  'How to attach file',
#  'How to edit attach file',
#  'How to creat googl drive file from wrike',
#  'How to download attach',
#  'How to delet attach',
#  'How to more info',
#  'How to creat mileston task',
#  'How to mileston on gantt chart',
#  'How to sort option',
#  'How to chang how task are sort',
#  'How to mass edit task',
#  'How to avail mass edit option',
#  'How to share task',
#  'How to unshar task',
#  'How to view who task is share with',
#  'How to duplic task',
#  'How to star task',
#  'How to set task import',
#  'How to avail task status',
#  'How to chang task statu',
#  'How to request statu updat',
#  'How to make task recurr',
#  'How to edit recurr',
#  'How to resum recurr',
#  'How to delet recurr',
#  'How to more resourc',
#  'How to delet task',
#  'How to delet task with subtask',
#  'How to restor delet task',
#  'How to perman delet task',
#  'How to print task list',
#  'How to creat folder',
#  'How to edit folder',
#  'How to open folder project info panel',
#  'How to navig info panel',
#  'How to use wizard',
#  'How to chang default view',
#  'How to creat subfold subproject',
#  'How to convert exist folder and project',
#  'How to share folder project',
#  'How to unshar folder project',
#  'How to view who folder project is share with',
#  'How to access role permiss',
#  'How to renam task',
#  'How to ',
#  'How to edit dashboard widget',
#  'How to creat and custom access role',
#  'How to delet access role',
#  'How to chang user group access role',
#  'How to inherit access role',
#  'How to access role and user group',
#  'How to duplic folder project',
#  'How to delet folder project',
#  'How to perman delet folder project',
#  'How to restor delet folder and project',
#  'How to add approv in task folder and project',
#  'How to approv task folder project',
#  'How to add approv to your workflow',
#  'How to approv in request form',
#  'How to see detail of finish approv',
#  'How to compat file type',
#  'How to proof in wrike',
#  'How to wrike proof comment export',
#  'How to video proof',
#  'How to comparison mode',
#  'How to add file to approv',
#  'How to import inform',
#  'How to enabl bynder integr',
#  'How to tag',
#  'How to publish file to bynder',
#  'How to attach file from bynder',
#  'How to map custom field to bynder metaproperti',
#  'How to edit file with document editor',
#  'How to instal document editor',
#  'How to support oper system and file type',
#  'How to set up proxi',
#  'How to support browser',
#  'How to configur your browser if necessari',
#  'How to mention right',
#  'How to mention teammat individu',
#  'How to mention segment of peopl',
#  'How to add comment',
#  'How to format comment',
#  'How to use comment reaction',
#  'How to repli to comment updat',
#  'How to view comment',
#  'How to edit comment',
#  'How to quot text in comment',
#  'How to delet comment',
#  'How to choos shortcut for ad comment',
#  'How to what sharing entail',
#  'How to privat task folder and project',
#  'How to inherit share',
#  'How to about select share',
#  'How to follow folder project',
#  'How to add other as follow',
#  'How to unfollow folder project',
#  'How to remov other from follow folder project',
#  'How to  ',
#  'How to avail shortcut',
#  'How to gantt chart shortcut',
#  'How to creat add and view custom field',
#  'How to field properti',
#  'How to share custom field',
#  'How to edit custom field',
#  'How to custom field histori',
#  'How to roll up custom field',
#  'How to aggreg and sort custom field data',
#  'How to arrang custom field on tabl view',
#  'How to hide custom field',
#  'How to open custom field manag',
#  'How to creat and add custom field',
#  'How to edit custom field',
#  'How to remov custom field',
#  'How to avail guid when to use them',
#  'How to use templat',
#  'How to edit default workflow',
#  'How to creat custom workflow',
#  'How to appli custom workflow',
#  'How to edit custom workflow',
#  'How to duplic workflow',
#  'How to delet custom workflow',
#  'How to autoassign base on statu',
#  'How to fix and flexibl workflow',
#  'How to creat request form',
#  'How to map respons',
#  'How to multipag request form',
#  'How to form builder respons map option',
#  'How to import',
#  'How to form builder avail question type',
#  'How to use case',
#  'How to submit a request form',
#  'How to make request form avail extern',
#  'How to find request form link and ifram htmlcode',
#  'How to custom email confirm',
#  'How to invalid request form link',
#  'How to creat folder project templ',
#  'How to use folder project templat',
#  'How to creat task templat',
#  'How to advanc tip',
#  'How to track time spent on task',
#  'How to preset',
#  'How to how wrike work with market workflow',
#  'How to featur',
#  'How to use',
#  'How to task folder and project',
#  'How to attach',
#  'How to regist for student account',
#  'How to use wrike for school',
#  'How to navig chart',
#  'How to hide show tabl',
#  'How to hide empti folder',
#  'How to add remov column from tabl',
#  'How to custom field on tabl',
#  'How to expand and collaps item on gantt chart',
#  'How to open task from gantt chart',
#  'How to weekend on gantt chart',
#  'How to undo your action',
#  'How to creat task from gantt chart',
#  'How to reschedul task from gantt chart',
#  'How to schedul backlog task on gantt chart',
#  'How to chang task durat from gantt chart',
#  'How to edit task on gantt chart',
#  'How to chang task hierarchi on gantt chart',
#  'How to delet task on gantt chart',
#  'How to type of depend',
#  'How to shift depend chain',
#  'How to remov depend',
#  'How to edit depend',
#  'How to lead and lag time',
#  'How to sort on gantt chart',
#  'How to chang sort order',
#  'How to manual reorder task on gantt chart',
#  'How to print timelin',
#  'How to adjust date rang on the gantt chart',
#  'How to enabl date roll up from lab',
#  'How to roll up date',
#  'How to date constraint on tabl',
#  'How to date constraint on timelin',
#  'How to creat gantt chart snapshot',
#  'How to view snapshot',
#  'How to edit snapshot',
#  'How to copi snapshot link',
#  'How to delet snapshot',
#  'How to view critic path',
#  'How to exampl',
#  'How to how to use workload chart',
#  'How to edit effort from tabl view and gantt chart',
#  'How to navig timesheet',
#  'How to custom timesheet',
#  'How to use timesheet',
#  'How to benefit of wrike report',
#  'How to creat wrike report',
#  'How to wrike report builder',
#  'How to custom field',
#  'How to open save wrike report',
#  'How to edit save wrike report',
#  'How to delet wrike report',
#  'How to share wrike report',
#  'How to best practic',
#  'How to group on tabl chart',
#  'How to edit and adjust tabl chart',
#  'How to 5',
#  'How to text wrap',
#  'How to undefin data',
#  'How to undefin column',
#  'How to edit column chart',
#  'How to group on column chart',
#  'How to who report can be share with',
#  'How to how to share report',
#  'How to what happen when you share report',
#  'How to avail templat',
#  'How to creat report snapshot',
#  'How to view report snapshot',
#  'How to delet report snapshot',
#  'How to creat calcul field',
#  'How to write formula',
#  'How to possibl formula and result data type',
#  'How to  ',
#  'How to add exist calcul field',
#  'How to edit calcul field',
#  'How to delet calcul field',
#  'How to schedul report remind',
#  'How to unsubscrib from report',
#  'How to ongo sync updat time and sync action',
#  'How to creat bitbucket issu from wrike',
#  'How to subtask and bitbucket integr',
#  'How to map and unmap field',
#  'How to creat gitlab issu from wrike',
#  'How to subtask and gitlab integr',
#  'How to creat github issu from wrike',
#  'How to subtask and github integr',
#  'How to comment',
#  'How to step 2',
#  'How to enabl wrike slack integr',
#  'How to wrike notif in slack',
#  'How to disabl wrike notif in slack',
#  'How to creat task from slack',
#  'How to more slash command',
#  'How to disabl integr',
#  'How to creat app',
#  'How to token',
#  'How to configur exist app',
#  'How to popular wrike zap',
#  'How to set up zap',
#  'How to benefit of link wrike with g suit',
#  'How to creat user account via g suit',
#  'How to login use googl credenti',
#  'How to benefit of link wrike with g suit',
#  'How to instal wrike app from g suit marketplac',
#  'How to creat wrike subscript via g suit',
#  'How to link exist wrike subscript with g suit',
#  'How to enabl googl calendar integr',
#  'How to edit event',
#  'How to delet event',
#  'How to situat',
#  'How to caus',
#  'How to solut',
#  'How to contact support',
#  'How to possibl solut',
#  'How to solut',
#  'How to websocket requir',
#  'How to check that websocket are working ',
#  'How to troubleshoot websocket',
#  'How to chang account owner',
#  'How to edit workweek',
#  'How to creat accountwid except',
#  'How to creat work schedul busi and enterpris',
#  'How to assign work schedul busi and enterpris',
#  'How to automat task reschedul',
#  'How to navig access report',
#  'How to run user access report',
#  'How to ensur data is share with right peopl',
#  'How to see what persongroup ha access to',
#  'How to export to csv',
#  'How to tag my team group in comment',
#  'How to share folder project with my team group',
#  'How to creat user group',
#  'How to add user to user group',
#  'How to move user between user group',
#  'How to creat subgroup',
#  'How to renam user group',
#  'How to edit group avatar',
#  'How to delet user group',
#  'How to access user manag chart',
#  'How to navig user manag chart',
#  'How to edit user name and email',
#  'How to chang user licens type',
#  'How to export list of user',
#  'How to mass action on user manag chart',
#  'How to who can log in as anoth user',
#  'How to how to log in as user',
#  'How to navig user manag chart ',
#  'How to invit user for regular user and admin',
#  'How to select “shar',
#  'How to invit user admin onli',
#  'How to restrict invit by domain for admin',
#  'How to admin permiss',
#  'How to account owner permiss',
#  'How to make user admin',
#  'How to upload compani logo for brand workspac',
#  'How to delet user',
#  'How to transfer data to anoth user in account',
#  'How to free account',
#  'How to all other account',
#  'How to set up wrike with onelogin scim',
#  'How to sync attribut',
#  'How to troubleshoot',
#  'How to set up wrike with okta scim',
#  'How to scroll down to admin credenti section',
#  'How to chang first day of week',
#  'How to chang languag set',
#  'How to creat calendar except',
#  'How to delet calendar except',
#  'How to navig daili todo email',
#  'How to interact with task on todo email',
#  'How to add email',
#  'How to set email as primari',
#  'How to delet email',
#  'How to chang your profil pictur',
#  'How to chang password',
#  'How to reset password',
#  'How to support charact and symbol',
#  'How to edit your person profil',
#  'How to edit date and time format',
#  'How to chang time zone set',
#  'How to privaci',
#  'How to creat addit account',
#  'How to switch between account',
#  'How to bill with multipl account',
#  'How to share',
#  'How to limit of singl signon',
#  'How to decid scope of singl signon',
#  'How to enabl singl signon',
#  'How to befor enabl sso',
#  'How to add approv email domain',
#  'How to access wrike via singl signon',
#  'How to login to wrike app with onetim password',
#  'How to ad new user',
#  'How to remov user',
#  'How to enabl singl signon',
#  'How to creat wrike user account via offic 365',
#  'How to log in to wrike use microsoft credenti',
#  'How to instal wrike on offic 365',
#  'How to creat wrike account via offic 365',
#  'How to configur user license registr set',
#  'How to migrat account to wrike eu data center',
#  'How to who can deactiv user',
#  'How to deactiv user',
#  'How to reactiv user',
#  'How to invit set',
#  'How to right to creat space',
#  'How to file storag set',
#  'How to 2step verif',
#  'How to network access polici',
#  'How to password strength polici set',
#  'How to password histori polici set',
#  'How to password expir polici set',
#  'How to what data is back up',
#  'How to perform account backup without attach',
#  'How to perform account backup with attach',
#  'How to authent app',
#  'How to enabl 2step verif for user licens',
#  'How to reconfigur 2step verif',
#  'How to disabl 2step verif for users licens']

# %%
vectorizer = TfidfVectorizer()
trans_matrix = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names())
# Out:
# ['2step', '365', 'about', 'access', 'account', 'accountwid', 'action', 'ad', 'add', 'addit', 'adjust', 'admin', 'advanc', 'aggreg', 'align', 'all', 'and', 'anoth', 'app', 'appli', 'approv', 'are', 'arrang', 'as', 'assign', 'attach', 'attribut', 'authent', 'autoassign', 'automat', 'avail', 'avatar', 'back', 'backlog', 'backup', 'base', 'be', 'befor', 'benefit', 'best', 'between', 'bill', 'bitbucket', 'brand', 'browser', 'builder', 'busi', 'by', 'bynder', 'calcul', 'calendar', 'can', 'case', 'caus', 'center', 'chain', 'chang', 'charact', 'chart', 'check', 'choos', 'collaps', 'column', 'command', 'comment', 'compani', 'comparison', 'compat', 'configur', 'confirm', 'constraint', 'contact', 'convert', 'copi', 'creat', 'credenti', 'critic', 'csv', 'custom', 'daili', 'dashboard', 'data', 'date', 'day', 'deactiv', 'decid', 'default', 'delet', 'depend', 'detail', 'disabl', 'document', 'domain', 'down', 'download', 'drive', 'duplic', 'durat', 'edit', 'editor', 'effort', 'email', 'empti', 'enabl', 'ensur', 'entail', 'enterpris', 'eu', 'event', 'exampl', 'except', 'exist', 'expand', 'expir', 'export', 'extern', 'featur', 'field', 'file', 'find', 'finish', 'first', 'fix', 'flexibl', 'folder', 'follow', 'for', 'form', 'format', 'formula', 'free', 'from', 'gantt', 'github', 'gitlab', 'googl', 'group', 'guid', 'ha', 'happen', 'hide', 'hierarchi', 'histori', 'how', 'htmlcode', 'if', 'ifram', 'import', 'in', 'individu', 'info', 'inform', 'inherit', 'instal', 'integr', 'interact', 'into', 'invalid', 'invit', 'is', 'issu', 'item', 'lab', 'lag', 'languag', 'lead', 'licens', 'license', 'limit', 'link', 'list', 'log', 'login', 'logo', 'make', 'manag', 'manual', 'map', 'market', 'marketplac', 'mass', 'mention', 'metaproperti', 'microsoft', 'migrat', 'mileston', 'mode', 'more', 'move', 'multipag', 'multipl', 'my', 'name', 'navig', 'necessari', 'network', 'new', 'notif', 'of', 'offic', 'okta', 'on', 'onelogin', 'onetim', 'ongo', 'onli', 'open', 'oper', 'option', 'order', 'organ', 'other', 'owner', 'panel', 'parent', 'password', 'path', 'peopl', 'perform', 'perman', 'permiss', 'person', 'persongroup', 'pictur', 'polici', 'popular', 'popup', 'possibl', 'practic', 'preset', 'primari', 'print', 'privaci', 'privat', 'profil', 'project', 'proof', 'properti', 'proxi', 'publish', 'question', 'quot', 'rang', 'reaction', 'reactiv', 'reconfigur', 'recurr', 'regist', 'registr', 'regular', 'remind', 'remov', 'renam', 'reorder', 'repli', 'report', 'request', 'requir', 'reschedul', 'reset', 'resourc', 'respons', 'restor', 'restrict', 'result', 'resum', 'right', 'role', 'roll', 'run', 'save', 'schedul', 'school', 'scim', 'scope', 'scroll', 'section', 'see', 'segment', 'select', 'set', 'shar', 'share', 'sharing', 'shift', 'shortcut', 'show', 'signon', 'singl', 'situat', 'slack', 'slash', 'snapshot', 'solut', 'sort', 'space', 'spent', 'sso', 'star', 'statu', 'status', 'step', 'storag', 'strength', 'student', 'subfold', 'subgroup', 'submit', 'subproject', 'subscript', 'subtask', 'suit', 'support', 'switch', 'symbol', 'sync', 'system', 'tabl', 'tag', 'task', 'team', 'teammat', 'templ', 'templat', 'text', 'that', 'the', 'them', 'time', 'timelin', 'timesheet', 'tip', 'to', 'todo', 'token', 'track', 'transfer', 'troubleshoot', 'type', 'undefin', 'undo', 'unfollow', 'unmap', 'unshar', 'unsubscrib', 'up', 'updat', 'upload', 'use', 'user', 'users', 'verif', 'via', 'video', 'view', 'websocket', 'week', 'weekend', 'what', 'when', 'who', 'widget', 'with', 'without', 'wizard', 'work', 'workflow', 'working', 'workload', 'workspac', 'workweek', 'wrap', 'wrike', 'write', 'you', 'your', 'zap', 'zone']

# %%
len(vectorizer.get_feature_names())
# Out:
# 378

# %%
def predict(request):
    norm_request = text_normalization(request)
    request_vector = vectorizer.transform([' '.join(norm_request)])
    
    #Finding max dot product (max similarity of sentences)
    n = 0
    max_dot = 0
    pred_title = ''
    for title in trans_matrix:
        res = np.dot(request_vector.toarray(), title.toarray().T)
        if(res > max_dot):
            max_dot = res
            pred_title = corpus[n]
        n += 1
    
    pred_row = data['How to ' + data['norm_title'].map(' '.join) == pred_title]
    pred_row.index = range(len(pred_row))
    if(len(pred_row) == 0):
        return "Couldn\'t find answer"
    else:
        title = 'How to ' + pred_row['title'][0]
        answer = pred_row['answer'][0]
        return title, answer

# %% [markdown]
# <h2>Examples of requests

# %%
predict('How to create a task')
# Out:
# ('How to create a task',
#  'Select a Folder or Project from the left-hand Folder tree (this is where your task will be created). Click the green plus sign in the Workspace\'s upper left-hand corner and select "Task". Type a task name and press "Enter". Your task is created and you can begin adding task attributes from the Task View (assignee, due dates, and more) or right-click on a task from the List View to access quick edit options.')

# %%
predict('I need create a task')
# Out:
# ('How to create a task',
#  'Select a Folder or Project from the left-hand Folder tree (this is where your task will be created). Click the green plus sign in the Workspace\'s upper left-hand corner and select "Task". Type a task name and press "Enter". Your task is created and you can begin adding task attributes from the Task View (assignee, due dates, and more) or right-click on a task from the List View to access quick edit options.')

# %%
predict('I need change view')
# Out:
# ('How to change the default view',
#  'Regular and External Users on all account types can change the default view of Folders and Projects. Change the default view for existing Folders and Projects. Right click on a Folder/Project from the Folder tree in the left-hand Navigation panel. Hover over “Set default view”. Select a view. The Folder/Project opens in this view whenever you (or anyone who the Folder is shared with) opens it.')
